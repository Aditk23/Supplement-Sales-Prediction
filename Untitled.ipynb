# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA, ARIMA
#from pyramid.arima import auto_arima
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
#from fbprophet import Prophet

from math import sqrt

import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
import seaborn as sns

from random import random

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_squared_log_error

# %%
train = pd.read_csv('TRAIN.csv')
test = pd.read_csv('TEST_FINAL.csv')

# %%
train.head(5)
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code        Date  Holiday Discount  #Order     Sales
# 0  T1000001         1         S1            L3          R1  2018-01-01        1      Yes       9   7011.84
# 1  T1000002       253         S4            L2          R1  2018-01-01        1      Yes      60  51789.12
# 2  T1000003       252         S3            L2          R1  2018-01-01        1      Yes      42  36868.20
# 3  T1000004       251         S2            L3          R1  2018-01-01        1      Yes      23  19715.16
# 4  T1000005       250         S2            L3          R4  2018-01-01        1      Yes      62  45614.52

# %%
train.drop(['ID','#Order'],axis=1,inplace=True)

# %%
train.Discount.value_counts()
# Out:
# No     104051
# Yes     84289
# Name: Discount, dtype: int64

# %%
train.Store_Type = train.Store_Type.map({'S1':1,'S2':2,'S3':3,'S4':4})
train.Location_Type = train.Location_Type.map({'L1':1,'L2':2,'L3':3,'L4':4,'L5':5})
train.Region_Code = train.Region_Code.map({'R1':1,'R2':2,'R3':3,'R4':4})
train.Discount = train.Discount.map({'No':0,'Yes':1})

# %%
train.head(10)
# Out:
#    Store_id  Store_Type  Location_Type  Region_Code        Date  Holiday  Discount     Sales
# 0         1           1              3            1  2018-01-01        1         1   7011.84
# 1       253           4              2            1  2018-01-01        1         1  51789.12
# 2       252           3              2            1  2018-01-01        1         1  36868.20
# 3       251           2              3            1  2018-01-01        1         1  19715.16
# 4       250           2              3            4  2018-01-01        1         1  45614.52
# 5       249           1              3            2  2018-01-01        1         1  34211.22
# 6       248           1              1            2  2018-01-01        1         1  35352.66
# 7       247           1              1            3  2018-01-01        1         1  52650.00
# 8       246           3              1            3  2018-01-01        1         1  42633.78
# ...

# %%
df = train.copy()
df['Date'] = pd.to_datetime(df['Date'])

# %%
y = df.set_index('Date')
y
# Out:
#             Store_id Store_Type Location_Type Region_Code  Holiday Discount     Sales
# Date
# 2018-01-01         1         S1            L3          R1        1      Yes   7011.84
# 2018-01-01       253         S4            L2          R1        1      Yes  51789.12
# 2018-01-01       252         S3            L2          R1        1      Yes  36868.20
# 2018-01-01       251         S2            L3          R1        1      Yes  19715.16
# 2018-01-01       250         S2            L3          R4        1      Yes  45614.52
# ...              ...        ...           ...         ...      ...      ...       ...
# 2019-05-31       149         S2            L3          R2        1      Yes  37272.00
# 2019-05-31       153         S4            L2          R1        1       No  54572.64
# 2019-05-31       154         S1            L3          R2        1       No  31624.56
# 2019-05-31       155         S3            L1          R2        1      Yes  49162.41
# ...

# %%
y.isnull().sum()
# Out:
# Store_id         0
# Store_Type       0
# Location_Type    0
# Region_Code      0
# Holiday          0
# Discount         0
# Sales            0
# dtype: int64

# %%
y.plot(figsize=(15, 6),y='Sales')
plt.show()

# %%
train.Store_id.value_counts()
# Out:
# 128    516
# 84     516
# 211    516
# 83     516
# 338    516
#       ...
# 168    516
# 40     516
# 295    516
# 167    516
# 255    516
# Name: Store_id, Length: 365, dtype: int64

# %%
test.Store_id.value_counts()
# Out:
# 16     61
# 362    61
# 330    61
# 314    61
# 298    61
#        ..
# 101    61
# 85     61
# 69     61
# 53     61
# 351    61
# Name: Store_id, Length: 365, dtype: int64

# %%
S1 = train.loc[train.Store_id==1]
S1['Date'] = pd.to_datetime(S1['Date'])
S1 = S1.set_index('Date')
S1.plot(figsize=(15, 6),y='Sales')
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(S1['Sales'], model='multiplicative')
fig = decomposition.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
#Perform Dickey-Fuller test:
print ('Results of Dickey-Fuller Test:')
dftest = adfuller(S1.Sales, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used',
                                         'Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print (dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.089691
# p-value                          0.001007
# #Lags Used                      13.000000
# Number of Observations Used    502.000000
# Critical Value (1%)             -3.443444
# Critical Value (5%)             -2.867315
# Critical Value (10%)            -2.569846
# dtype: float64

# %%
ts = S1.Sales - S1.Sales.shift()
ts.dropna(inplace=True)

# %%
from matplotlib import pyplot
pyplot.figure()
pyplot.subplot(211)
plot_acf(ts, ax=pyplot.gca(),lags=30)
pyplot.subplot(212)
plot_pacf(ts, ax=pyplot.gca(),lags=30)
pyplot.show()

# %%
train = S1[:int(0.75*(len(S1)))]
valid = S1[int(0.75*(len(S1))):]

#plotting the data
train['Sales'].plot()
valid['Sales'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

model = ARIMA(train.values.reshape(-1).tolist(), order=(2,1,2))
#model = ARIMA(train, order=(1, 1, 1))
model_fit = model.fit(disp=1)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                 2708
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -29286.166
# Method:                       css-mle   S.D. of innovations          12017.122
# Date:                Sun, 19 Sep 2021   AIC                          58584.332
# Time:                        17:44:47   BIC                          58619.755
# Sample:                             1   HQIC                         58597.140
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0462      0.250      0.185      0.853      -0.444       0.536
# ar.L1.D.y     -1.0059      0.019    -52.444      0.000      -1.043      -0.968
# ar.L2.D.y     -0.2743      0.019    -14.678      0.000      -0.311      -0.238
# ...

# %%
start_index = valid.index.min()
end_index = valid.index.max()

#Predictions
predictions = model_fit.predict(start=start_index, end=end_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     223             if not isinstance(key, (int, np.integer)):
# --> 224                 loc = row_labels.get_loc(key)
#     225             else:
#
# AttributeError: 'NoneType' object has no attribute 'get_loc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-b08fda1adc65> in <module>
#       3
#       4 #Predictions
# ----> 5 predictions = model_fit.predict(start=start_index, end=end_index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
# ...

# %%
S1
# Out:
#             Store_id  Store_Type  Location_Type  Region_Code  Holiday  Discount     Sales
# Date
# 2018-01-01         1           1              3            1        1         1   7011.84
# 2018-01-02         1           1              3            1        0         1  42369.00
# 2018-01-03         1           1              3            1        0         1  50037.00
# 2018-01-04         1           1              3            1        0         1  44397.00
# 2018-01-05         1           1              3            1        0         1  47604.00
# ...              ...         ...            ...          ...      ...       ...       ...
# 2019-05-27         1           1              3            1        0         1  33075.00
# 2019-05-28         1           1              3            1        0         1  37317.00
# 2019-05-29         1           1              3            1        0         1  44652.00
# ...

# %%
S1["Sales1"] = S1["Sales"].shift(1)
S1.shape
# Out:
# (516, 8)

# %%
S1
# Out:
#             Store_id  Store_Type  Location_Type  Region_Code  Holiday  Discount     Sales    Sales1
# Date
# 2018-01-01         1           1              3            1        1         1   7011.84       NaN
# 2018-01-02         1           1              3            1        0         1  42369.00   7011.84
# 2018-01-03         1           1              3            1        0         1  50037.00  42369.00
# 2018-01-04         1           1              3            1        0         1  44397.00  50037.00
# 2018-01-05         1           1              3            1        0         1  47604.00  44397.00
# ...              ...         ...            ...          ...      ...       ...       ...       ...
# 2019-05-27         1           1              3            1        0         1  33075.00  25035.00
# 2019-05-28         1           1              3            1        0         1  37317.00  33075.00
# ...

# %%
df.set_index(["Date"]).shift(1)
# Out:
#             Store_id  Store_Type  Location_Type  Region_Code  Holiday  Discount     Sales
# Date
# 2018-01-01       NaN         NaN            NaN          NaN      NaN       NaN       NaN
# 2018-01-01       1.0         1.0            3.0          1.0      1.0       1.0   7011.84
# 2018-01-01     253.0         4.0            2.0          1.0      1.0       1.0  51789.12
# 2018-01-01     252.0         3.0            2.0          1.0      1.0       1.0  36868.20
# 2018-01-01     251.0         2.0            3.0          1.0      1.0       1.0  19715.16
# ...              ...         ...            ...          ...      ...       ...       ...
# 2019-05-31     151.0         1.0            3.0          2.0      1.0       0.0  24105.60
# 2019-05-31     149.0         2.0            3.0          2.0      1.0       1.0  37272.00
# 2019-05-31     153.0         4.0            2.0          1.0      1.0       0.0  54572.64
# ...

# %%
y
# Out:
#             Store_id Store_Type Location_Type Region_Code  Holiday Discount     Sales
# Date
# 2018-01-01         1         S1            L3          R1        1      Yes   7011.84
# 2018-01-01       253         S4            L2          R1        1      Yes  51789.12
# 2018-01-01       252         S3            L2          R1        1      Yes  36868.20
# 2018-01-01       251         S2            L3          R1        1      Yes  19715.16
# 2018-01-01       250         S2            L3          R4        1      Yes  45614.52
# ...              ...        ...           ...         ...      ...      ...       ...
# 2019-05-31       149         S2            L3          R2        1      Yes  37272.00
# 2019-05-31       153         S4            L2          R1        1       No  54572.64
# 2019-05-31       154         S1            L3          R2        1       No  31624.56
# 2019-05-31       155         S3            L1          R2        1      Yes  49162.41
# ...

# %%
S2 = train.loc[train.Store_id==2]
S2
# Out:
#         Store_id Store_Type Location_Type Region_Code        Date  Holiday Discount     Sales
# 114            2         S3            L1          R3  2018-01-01        1      Yes  18137.52
# 598            2         S3            L1          R3  2018-01-02        0      Yes  62976.00
# 1070           2         S3            L1          R3  2018-01-03        0      Yes  54057.00
# 1395           2         S3            L1          R3  2018-01-04        0      Yes  62379.00
# 1621           2         S3            L1          R3  2018-01-05        0      Yes  57780.00
# ...          ...        ...           ...         ...         ...      ...      ...       ...
# 186621         2         S3            L1          R3  2019-05-27        0      Yes  60093.00
# 187054         2         S3            L1          R3  2019-05-28        0      Yes  63969.00
# 187374         2         S3            L1          R3  2019-05-29        0       No  28233.00
# ...

# %%
S2['Date'] = pd.to_datetime(S2['Date'])
S2 = S2.set_index('Date')

# %%
S2
# Out:
#             Store_id Store_Type Location_Type Region_Code  Holiday Discount     Sales
# Date
# 2018-01-01         2         S3            L1          R3        1      Yes  18137.52
# 2018-01-02         2         S3            L1          R3        0      Yes  62976.00
# 2018-01-03         2         S3            L1          R3        0      Yes  54057.00
# 2018-01-04         2         S3            L1          R3        0      Yes  62379.00
# 2018-01-05         2         S3            L1          R3        0      Yes  57780.00
# ...              ...        ...           ...         ...      ...      ...       ...
# 2019-05-27         2         S3            L1          R3        0      Yes  60093.00
# 2019-05-28         2         S3            L1          R3        0      Yes  63969.00
# 2019-05-29         2         S3            L1          R3        0       No  28233.00
# 2019-05-30         2         S3            L1          R3        0       No  44817.00
# ...

# %%
S2.shift(1)
#S2.set_index(["Date"]).shift(1)
# Out:
#             Store_id Store_Type Location_Type Region_Code  Holiday Discount     Sales
# Date
# 2018-01-01       NaN        NaN           NaN         NaN      NaN      NaN       NaN
# 2018-01-02       2.0         S3            L1          R3      1.0      Yes  18137.52
# 2018-01-03       2.0         S3            L1          R3      0.0      Yes  62976.00
# 2018-01-04       2.0         S3            L1          R3      0.0      Yes  54057.00
# 2018-01-05       2.0         S3            L1          R3      0.0      Yes  62379.00
# ...              ...        ...           ...         ...      ...      ...       ...
# 2019-05-27       2.0         S3            L1          R3      0.0      Yes  68364.00
# 2019-05-28       2.0         S3            L1          R3      0.0      Yes  60093.00
# 2019-05-29       2.0         S3            L1          R3      0.0      Yes  63969.00
# 2019-05-30       2.0         S3            L1          R3      0.0       No  28233.00
# ...

# %%
S2['Sales1'] = df['Sales'].shift(1)
S2
# Out:
#         Store_id Store_Type Location_Type Region_Code        Date  Holiday Discount     Sales    Sales1
# 114            2         S3            L1          R3  2018-01-01        1      Yes  18137.52  37962.45
# 598            2         S3            L1          R3  2018-01-02        0      Yes  62976.00  53073.00
# 1070           2         S3            L1          R3  2018-01-03        0      Yes  54057.00  35994.00
# 1395           2         S3            L1          R3  2018-01-04        0      Yes  62379.00  52773.00
# 1621           2         S3            L1          R3  2018-01-05        0      Yes  57780.00  63537.00
# ...          ...        ...           ...         ...         ...      ...      ...       ...       ...
# 186621         2         S3            L1          R3  2019-05-27        0      Yes  60093.00  41811.00
# 187054         2         S3            L1          R3  2019-05-28        0      Yes  63969.00  56868.00
# ...
